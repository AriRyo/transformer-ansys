# %%
import random
import operator
import math

# 数式生成に使うオペレータと対応するPythonの演算子
operators = {
    '+': operator.add,
    '-': operator.sub,
    '*': operator.mul,
    # '/': operator.truediv,
}

# ランダムな数式を生成する関数
def generate_expression(depth=0):
    if depth >= 1 and random.random() < 0.7:
        # 数字のみを返す
        return str(random.randint(1, 10))
    else:
        # 深さを増やしながら再帰的に数式を生成
        op = random.choice(list(operators.keys()))
        left = generate_expression(depth + 1)
        right = generate_expression(depth + 1)
        return f"({left}{op}{right})"

# 数式の計算結果を得る関数
def evaluate_expression(expr):
    try:
        # evalを使って数式を評価し、四捨五入する
        result = eval(expr)
        return round(result, 2)  # 小数点以下2桁に丸める
    except ZeroDivisionError:
        return 'NaN'

# 数式を生成して計算結果を加える
def create_equation():
    expr = generate_expression()
    result = evaluate_expression(expr)
    return f"{expr}={result}"

# 100個の数式を生成してテキストファイルに保存
def generate_equations_to_file(test=True, filename="data/equations.txt", num_equations=100):
    if test:
        for _ in range(num_equations):
            equation = create_equation()
            print(equation)
        return
    with open(filename, 'w') as file:
        for _ in range(num_equations):
            equation = create_equation()
            file.write(equation + '\n')

generate_equations_to_file(test=True)
# Out:
# (4+((9-1)+3)) = 15
# ((2*6)+10) = 22
# (6*2) = 12
# ((1-2)-4) = -5
# ((10*6)+((1-3)+(6-5))) = 59
# ((2-10)-10) = -18
# ((10-1)-(1-(2*4))) = 16
# (7+7) = 14
# (2-((10+10)*9)) = -178
# ((8+(8*(((5*8)-10)-3)))+8) = 232
# (5+8) = 13
# ((2+7)+6) = 15
# ((9-8)+(4-8)) = -3
# (10*10) = 100
# (9+1) = 10
# (6+1) = 7
# (7*(3*6)) = 126
# (8*10) = 80
# ((3+8)-2) = 9
# (10-4) = 6
# ((10+3)*3) = 39
# (7-2) = 5
# ((((8-9)-3)*(8+(10-1)))-9) = -77
# (4-(2*1)) = 2
# (((5*9)-3)+(1+((((2-(4*5))*8)-(1-6))*((((((10+(5+(1+6)))-3)-(8+3))-9)*6)*(6*9))))) = 45079
# (7*7) = 49
# (5*(10-3)) = 35
# (2*4) = 8
# (2-(5*5)) = -23
# (5*6) = 30
# (6-1) = 5
# (4+1) = 5
# (1-8) = -7
# ((9*6)-3) = 51
# ((1*7)+((8-7)+6)) = 14
# (3-1) = 2
# (5+9) = 14
# (10+9) = 19
# ((6+3)*7) = 63
# (7-8) = -1
# (5*10) = 50
# (8+6) = 14
# ((8+1)*3) = 27
# ((4*(1-2))+2) = -2
# (10-7) = 3
# (8+1) = 9
# (6+(1-3)) = 4
# ((3-((3+2)+(6-10)))*(8*8)) = 128
# (((10-3)*(6+(6*(5+1))))+8) = 302
# (7-4) = 3
# (4-4) = 0
# (10*(2+(3*(1-9)))) = -220
# (6+5) = 11
# (8*6) = 48
# (3-6) = -3
# (((7+3)+6)+(3-4)) = 15
# (((3-(8+2))+1)+2) = -4
# (9*6) = 54
# ((2*(7+1))-5) = 11
# ((10-3)+7) = 14
# (5+4) = 9
# ((((3-(5-((1*8)-5)))+2)*7)-4) = 17
# (5+9) = 14
# (10+3) = 13
# ((10+(((1-(1+((((1-7)*9)+6)+(10+((10-4)+7)))))-2)*1))*6) = 198
# (8+4) = 12
# (10*6) = 60
# (5+1) = 6
# ((10*8)-1) = 79
# ((7-9)-9) = -11
# ((10*5)-(6-4)) = 48
# (4+(9-(6+2))) = 5
# (10+9) = 19
# (7*3) = 21
# (9-((2*2)-4)) = 9
# ((6*4)+6) = 30
# (7*10) = 70
# (4+5) = 9
# (2*9) = 18
# (2*2) = 4
# (10-6) = 4
# (10+2) = 12
# ((((6-9)*1)+7)*(1-5)) = -16
# ((3+3)+9) = 15
# (8-7) = 1
# (9-5) = 4
# (2+3) = 5
# (8*7) = 56
# (4+7) = 11
# (((7*5)*(8*(7-2)))-10) = 1390
# (2+5) = 7
# (9*10) = 90
# (((8+((10-(6*7))-(7-9)))*5)-9) = -119
# ((((9+(3*10))+8)-(5+(7-9)))-10) = 34
# ((((1+8)+6)+9)*3) = 72
# (3*(1*8)) = 24
# (1+(7+4)) = 12
# (8+6) = 14
# (2*(9+(10*1))) = 38
# (10*7) = 70

# %%
# 実行
generate_equations_to_file(test=False, num_equations=1000000)
